# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
print('Hello World')
# Out:
# Hello World

# %%
name='Fern'
print('Hello '+ name +'are u ok?')
# Out:
# Hello Fernare u ok?

# %%
country = input('Where are u?')
print(country)
# Out:
# Where are u? Chiang Mai
# Chiang Mai

# %%
print('I am from '+country)
# Out:
# I am from Chiang Mai

# %%
age = input('What is your age = ')
# Out:
# What is your age =  20

# %%
print('I am '+age+' years old.')
# Out:
# I am 20 years old.

# %% [markdown]
# **Ex. ข้อ1 แก้ Error**

# %% [markdown]
# วิธีที่1

# %%
age=int(input('Type your age: '))
tenyears_age = age + 10
print(tenyears_age)
# Out:
# Type your age:  20
# 30

# %% [markdown]
# วิธีที่2

# %%
age=input('Type your age: ')
tenyears_age = int(age) + 10
print(tenyears_age)
# Out:
# Type your age:  20
# 30

# %% [markdown]
# **EX.2 แก้ error******

# %%
pi=3.14
print(pi)
# Out:
# 3.14

# %% [markdown]
# วิธีที่1

# %%
print('pi is equal to '+ str(pi))
# Out:
# pi is equal to 3.14

# %% [markdown]
# วิธีที่2

# %%
print('pi is equal to ',pi)
# Out:
# pi is equal to  3.14

# %% [markdown]
# **EX.3 **

# %%
a = int(input("What is your A = "))
b = int(input("What is your B = "))
c=a+b
print('ANS =',c)
# Out:
# What is your A =  5
# What is your B =  5
# ANS = 10

# %%
a="Bai"
b="fern"
print(f"My name is {a} and my last name is {b}")
# Out:
# My name is Bai and my last name is fern

# %%
a="price"
b=2000
print(a+' is %.2f'% b)
# Out:
# price is 2000.00

# %%
a.upper()
# Out:
# 'PRICE'

# %%
a.lower()
# Out:
# 'price'

# %%
a = "Baifern ja"
a.find("ja")
# Out:
# 8

# %%
a = "Baifern ja"
a2=a.replace("Bai","Nong")
a3=a2.upper()
print(a3)
# Out:
# NONGFERN JA

# %%
", ".join('ABC')
# Out:
# 'A, B, C'

# %% [markdown]
# EX.4

# %%
a="Hello World"
list_a=[a[0:5],a[6:11]]
print(list_a)
# Out:
# ['Hello', 'World']

# %%
a="Hello World"
a.split()
# Out:
# ['Hello', 'World']

# %% [markdown]
# EX.5

# %%
L=[[1,2,3],[4,5,6],[7,8,9]]
L.sort(reverse=True)
L
# Out:
# [[7, 8, 9], [4, 5, 6], [1, 2, 3]]
